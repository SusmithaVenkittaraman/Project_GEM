# %%
import pandas as pd
from sqlalchemy import create_engine
from db_config import password

# %%
engine = create_engine(f"postgresql://postgres:{password}@localhost:5432/gem_db")
connection = engine.connect()

# %%
db_BA=pd.read_sql("select * from behavior_and_attitudes",connection)
db_BA.head()
# Out:
#    index  code    Country  year  Perceived_opportunities  \
# 0      0   374    Armenia  2019                    53.89
# 1      1    61  Australia  2019                    45.74
# 2      2   375    Belarus  2019                    29.52
# 3      3    55     Brazil  2019                    46.37
# 4      4   101     Canada  2019                    67.08
#
#    Perceived_capabilities  Fear_of_failure_rate  Entrepreneurial_intentions  \
# 0                   70.00                 48.22                       32.20
# 1                   56.04                 47.37                       13.02
# 2                   42.34                 37.96                        6.59
# 3                   61.99                 35.57                       30.17
# 4                   56.80                 47.17                       11.86
#
#    Total_early_stage_Entrepreneurial_Activity  Established_Business_Ownership  \
# 0                                       20.97                            7.84
# 1                                       10.52                            6.53
# 2                                        5.78                            2.72
# 3                                       23.30                           16.16
# 4                                       18.16                            7.44
#
#    Entrepreneurial_Employee_Activity  Motivational_Index  Female_Male_TEA  \
# 0                               0.59                 NaN             0.64
# 1                               8.28                 NaN             0.72
# 2                               0.49                 NaN             0.82
# 3                               0.62                 NaN             0.98
# 4                               5.40                 NaN             0.71
#
#    Female_Male_Opportunity_Driven_TEA  High_Job_Creation_Expectation  \
# 0                                 NaN                          30.55
# 1                                 NaN                          24.64
# 2                                 NaN                          28.23
# 3                                 NaN                           8.93
# 4                                 NaN                          21.18
#
#    Innovation  Business_Services_Sector  \
# 0         NaN                      7.55
# 1         NaN                     26.31
# 2         NaN                     10.16
# 3         NaN                      7.57
# 4         NaN                     12.24
#
#    High_Status_to_Successful_Entrepreneurs  \
# 0                                    73.41
# 1                                    74.00
# 2                                    69.90
# 3                                    72.25
# 4                                    79.90
#
#    Entrepreneurship_as_a_Good_Career_Choice
# 0                                     87.24
# 1                                     56.39
# 2                                     70.30
# 3                                     75.25
# 4                                     69.21

# %%
db_BA["Country"]
db_BA.columns
# Out:
# Index(['index', 'code', 'Country', 'year', 'Perceived_opportunities',
#        'Perceived_capabilities', 'Fear_of_failure_rate',
#        'Entrepreneurial_intentions',
#        'Total_early_stage_Entrepreneurial_Activity',
#        'Established_Business_Ownership', 'Entrepreneurial_Employee_Activity',
#        'Motivational_Index', 'Female_Male_TEA',
#        'Female_Male_Opportunity_Driven_TEA', 'High_Job_Creation_Expectation',
#        'Innovation', 'Business_Services_Sector',
#        'High_Status_to_Successful_Entrepreneurs',
#        'Entrepreneurship_as_a_Good_Career_Choice'],
#       dtype='object')

# %%
list_BA=[]
for rows in db_BA.iterrows():
    row_dict={'code':rows[1].code,
             'country':rows[1].Country,
             'year':rows[1].year,
             'Perceived_opportunities':rows[1].Perceived_opportunities,
             'Perceived_capabilities':rows[1].Perceived_capabilities,
             'Fear_of_failure_rate':rows[1].Fear_of_failure_rate,
             'Entrepreneurial_intentions':rows[1].Entrepreneurial_intentions,
             'Total_early_stage_Entrepreneurial_Activity':rows[1].Total_early_stage_Entrepreneurial_Activity,
             'Established_Business_Ownership':rows[1].Established_Business_Ownership,
             'Entrepreneurial_Employee_Activity':rows[1].Entrepreneurial_Employee_Activity,
             'Motivational_Index':rows[1].Motivational_Index,
             'Female_Male_TEA':rows[1].Female_Male_TEA,
             'Female_Male_Opportunity_Driven_TEA':rows[1].Female_Male_Opportunity_Driven_TEA,
             'High_Job_Creation_Expectation':rows[1].High_Job_Creation_Expectation,
             'Innovation':rows[1].Innovation,
             'Business_Services_Sector':rows[1].Business_Services_Sector,
             'High_Status_to_Successful_Entrepreneurs':rows[1].High_Status_to_Successful_Entrepreneurs,
             'Entrepreneurship_as_a_Good_Career_Choice':rows[1].Entrepreneurship_as_a_Good_Career_Choice
            }
    list_BA.append(row_dict)
print(list_BA)
# Out:
# [{'code': 374, 'country': 'Armenia', 'year': 2019, 'Perceived_opportunities': 53.89, 'Perceived_capabilities': 70.0, 'Fear_of_failure_rate': 48.22, 'Entrepreneurial_intentions': 32.2, 'Total_early_stage_Entrepreneurial_Activity': 20.97, 'Established_Business_Ownership': 7.84, 'Entrepreneurial_Employee_Activity': 0.59, 'Motivational_Index': nan, 'Female_Male_TEA': 0.64, 'Female_Male_Opportunity_Driven_TEA': nan, 'High_Job_Creation_Expectation': 30.55, 'Innovation': nan, 'Business_Services_Sector': 7.55, 'High_Status_to_Successful_Entrepreneurs': 73.41, 'Entrepreneurship_as_a_Good_Career_Choice': 87.24}, {'code': 61, 'country': 'Australia', 'year': 2019, 'Perceived_opportunities': 45.74, 'Perceived_capabilities': 56.04, 'Fear_of_failure_rate': 47.37, 'Entrepreneurial_intentions': 13.02, 'Total_early_stage_Entrepreneurial_Activity': 10.52, 'Established_Business_Ownership': 6.53, 'Entrepreneurial_Employee_Activity': 8.28, 'Motivational_Index': nan, 'Female_Male_TEA': 0.72, 'Female_Male_Opportunity_Driven_TEA': nan, 'High_Job_Creation_Expectation': 24.64, 'Innovation': nan, 'Business_Services_Sector': 26.31, 'High_Status_to_Successful_Entrepreneurs': 74.0, 'Entrepreneurship_as_a_Good_Career_Choice': 56.39}, {'code': 375, 'country': 'Belarus', 'year': 2019, 'Perceived_opportunities': 29.52, 'Perceived_capabilities': 42.34, 'Fear_of_failure_rate': 37.96, 'Entrepreneurial_intentions': 6.59, 'Total_early_stage_Entrepreneurial_Activity': 5.78, 'Established_Business_Ownership': 2.72, 'Entrepreneurial_Employee_Activity': 0.49, 'Motivational_Index': nan, 'Female_Male_TEA': 0.82, 'Female_Male_Opportunity_Driven_TEA': nan, 'High_Job_Creation_Expectation': 28.23, 'Innovation': nan, 'Business_Services_Sector': 10.16, 'High_Status_to_Successful_Entrepreneurs': 69.9, 'Entrepreneurship_as_a_Good_Career_Choice': 70.3}, {'code': 55, 'country': 'Brazil', 'year': 2019, 'Perceived_opportunities': 46.37, 'Perceived_capabilities': 61.99, 'Fear_of_failure_rate': 35.57, 'Entrepreneurial_intentions': 30.17, 'Total_early_stage_Entrepreneurial_Activity': 23.3, 'Established_Business_Ownership': 16.16, 'Entrepreneurial_Employee_Activity': 0.62, 'Motivational_Index': nan, 'Female_Male_TEA': 0.98, 'Female_Male_Opportunity_Driven_TEA': nan, 'High_Job_Creation_Expectation': 8.93, 'Innovation': nan, 'Business_Services_Sector': 7.57, 'High_Status_to_Successful_Entrepreneurs': 72.25, 'Entrepreneurship_as_a_Good_Career_Choice': 75.25}, {'code': 101, 'country': 'Canada', 'year': 2019, 'Perceived_opportunities': 67.08, 'Perceived_capabilities': 56.8, 'Fear_of_failure_rate': 47.17, 'Entrepreneurial_intentions': 11.86, 'Total_early_stage_Entrepreneurial_Activity': 18.16, 'Established_Business_Ownership': 7.44, 'Entrepreneurial_Employee_Activity': 5.4, 'Motivational_Index': nan, 'Female_Male_TEA': 0.71, 'Female_Male_Opportunity_Driven_TEA': nan, 'High_Job_Creation_Expectation': 21.18, 'Innovation': nan, 'Business_Services_Sector': 12.24, 'High_Status_to_Successful_Entrepreneurs': 79.9, 'Entrepreneurship_as_a_Good_Career_Choice': 69.21}, {'code': 56, 'country': 'Chile', 'year': 2019, 'Perceived_opportunities': 47.62, 'Perceived_capabilities': 75.54, 'Fear_of_failure_rate': 58.07, 'Entrepreneurial_intentions': 57.57, 'Total_early_stage_Entrepreneurial_Activity': 36.71, 'Established_Business_Ownership': 10.61, 'Entrepreneurial_Employee_Activity': 3.64, 'Motivational_Index': nan, 'Female_Male_TEA': 0.79, 'Female_Male_Opportunity_Driven_TEA': nan, 'High_Job_Creation_Expectation': 36.34, 'Innovation': nan, 'Business_Services_Sector': 19.9, 'High_Status_to_Successful_Entrepreneurs': 74.58, 'Entrepreneurship_as_a_Good_Career_Choice': 74.36}, {'code': 86, 'country': 'China', 'year': 2019, 'Perceived_opportunities': 74.86, 'Perceived_capabilities': 67.35, 'Fear_of_failure_rate': 44.65, 'Entrepreneurial_intentions': 21.42, 'Total_early_stage_Entrepreneurial_Activity': 8.66, 'Established_Business_Ownership': 9.33, 'Entrepreneurial_Employee_Activity': 0.16, 'Motivational_Index': nan, ' ...

# %%
db_BA.fillna(value='')
# Out:
#      index  code         Country  year  Perceived_opportunities  \
# 0        0   374         Armenia  2019                    53.89
# 1        1    61       Australia  2019                    45.74
# 2        2   375         Belarus  2019                    29.52
# 3        3    55          Brazil  2019                    46.37
# 4        4   101          Canada  2019                    67.08
# ..     ...   ...             ...   ...                      ...
# 939    939    82     South Korea  2001                    12.24
# 940    940    34           Spain  2001                    48.46
# 941    941    46          Sweden  2001                    42.34
# 942    942    44  United Kingdom  2001                    23.00
# 943    943     1   United States  2001                    34.89
#
#      Perceived_capabilities  Fear_of_failure_rate Entrepreneurial_intentions  \
# 0                     70.00                 48.22                       32.2
# 1                     56.04                 47.37                      13.02
# 2                     42.34                 37.96                       6.59
# 3                     61.99                 35.57                      30.17
# 4                     56.80                 47.17                      11.86
# ..                      ...                   ...                        ...
# 939                   28.55                 43.55
# 940                   48.65                 36.22
# 941                   44.41                 31.19
# 942                   45.96                 33.24
# 943                   60.59                 21.37
#
#      Total_early_stage_Entrepreneurial_Activity  \
# 0                                         20.97
# 1                                         10.52
# 2                                          5.78
# 3                                         23.30
# 4                                         18.16
# ..                                          ...
# 939                                       14.32
# 940                                        6.32
# 941                                        5.65
# 942                                        6.49
# 943                                       11.07
#
#      Established_Business_Ownership Entrepreneurial_Employee_Activity  \
# 0                              7.84                              0.59
# 1                              6.53                              8.28
# 2                              2.72                              0.49
# 3                             16.16                              0.62
# 4                              7.44                               5.4
# ..                              ...                               ...
# 939                           10.47
# 940                            4.72
# 941                            5.65
# 942                            3.35
# 943                            5.83
#
#     Motivational_Index  Female_Male_TEA Female_Male_Opportunity_Driven_TEA  \
# 0                                  0.64
# 1                                  0.72
# 2                                  0.82
# 3                                  0.98
# 4                                  0.71
# ..                 ...              ...                                ...
# 939                                0.42
# 940                                0.71
# 941                                0.59
# 942                                0.39
# 943                                0.68
#
#     High_Job_Creation_Expectation Innovation Business_Services_Sector  \
# 0                           30.55                                7.55
# 1                           24.64                               26.31
# 2                           28.23                               10.16
# 3                            8.93                                7.57
# 4                           21.18                               12.24
# ..                            ...        ...                      ...
# 939                         19.36                               15.83
# 940                         12.97                               22.38
# 941                         25.72                               34.33
# 942                         17.46                               27.53
# 943                         26.31                               30.56
#
#     High_Status_to_Successful_Entrepreneurs  \
# 0                                     73.41
# 1                                        74
# 2                                      69.9
# 3                                     72.25
# 4                                      79.9
# ..                                      ...
# 939
# 940
# 941
# 942
# 943
#
#     Entrepreneurship_as_a_Good_Career_Choice
# 0                                      87.24
# 1                                      56.39
# 2                                       70.3
# 3                                      75.25
# 4                                      69.21
# ..                                       ...
# 939
# 940
# 941
# 942
# 943
#
# [944 rows x 19 columns]
