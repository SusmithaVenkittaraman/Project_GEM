# %% [markdown]
# ### Dependencies for the Project

# %%
import pandas as pd

# %% [markdown]
# ### Importing the CSV file for Behavior and Attitudes

# %%
file = "./Behavior_and_Attitudes.csv"
file2 = "./policies.csv"
df_BA = pd.read_csv(file)
df_p = pd.read_csv(file2)
df_p.head()
# Out:
#    code    economy  year  Financing for entrepreneurs  \
# 0   374    Armenia  2019                         2.48
# 1    61  Australia  2019                         3.10
# 2   375    Belarus  2019                         2.21
# 3    55     Brazil  2019                         2.93
# 4   359   Bulgaria  2019                         2.75
#
#    Governmental support and policies  Taxes and bureaucracy  \
# 0                               2.69                   3.19
# 1                               2.62                   2.70
# 2                               2.28                   2.73
# 3                               2.50                   1.87
# 4                               1.89                   2.80
#
#    Governmental programs  Basic school entrepreneurial education and training  \
# 0                   2.42                                               2.06
# 1                   2.82                                               2.43
# 2                   2.12                                               2.00
# 3                   2.56                                               1.78
# 4                   2.07                                               1.95
#
#    Post school entrepreneurial education and training  R&D transfer  \
# 0                                               2.37           2.16
# 1                                               2.81           2.52
# 2                                               2.86           2.30
# 3                                               2.67           2.25
# 4                                               2.53           2.17
#
#    Commercial and professional infrastructure  Internal market dynamics  \
# 0                                        3.35                      3.12
# 1                                        3.09                      2.70
# 2                                        3.10                      3.28
# 3                                        2.82                      3.44
# 4                                        3.03                      3.10
#
#    Internal market openness  Physical and services infrastructure  \
# 0                      2.76                                  3.91
# 1                      2.88                                  3.53
# 2                      2.67                                  4.08
# 3                      2.49                                  3.23
# 4                      2.68                                  4.09
#
#    Cultural and social norms
# 0                       3.55
# 1                       3.15
# 2                       2.39
# 3                       2.47
# 4                       2.50

# %% [markdown]
# ### Exploring the Database

# %% [markdown]
# #### No of unique countries in the Survey

# %%
print(f"No of unique countries in the survey : {len(df_BA['economy'].unique())}")
# Out:
# No of unique countries in the survey : 113

# %% [markdown]
# #### Understanding the Number of economies every year.
#
# We could see that not every country is been surveyed in all the years. 2001 was the year with minimum countries(28) in the survey and 2013 and 2014 had 70 countries participating. The latest year 2019 have 50 economies surveyed.

# %%
df_BA["year"].value_counts()
# Out:
# 2014    70
# 2013    70
# 2012    67
# 2016    64
# 2015    60
# 2010    59
# 2011    55
# 2009    54
# 2017    54
# 2019    50
# 2018    49
# 2008    43
# 2007    42
# 2006    42
# 2002    37
# 2005    35
# 2004    34
# 2003    31
# 2001    28
# Name: year, dtype: int64

# %% [markdown]
# #### Null Values
#
# The dataset have null values in certain column and that has been identified below. The columns with null values are,
# 1. Fear of failure rate *
# 2. Entrepreneurial intentions
# 3. Established Business Ownership
# 4. Entrepreneurial Employee Activity
# 5. Motivational Index
# 6. Female/Male Opportunity-Driven TEA
# 7. High Job Creation Expectation
# 8. Innovation
# 9. Business Services Sector
# 10. High Status to Successful Entrepreneurs
# 11. Entrepreneurship as a Good Career Choice

# %%
# identifying missing values
df_BA.count()
# Out:
# code                                                944
# economy                                             944
# year                                                944
# Perceived opportunities                             944
# Perceived capabilities                              944
# Fear of failure rate *                              943
# Entrepreneurial intentions                          916
# Total early-stage Entrepreneurial Activity (TEA)    944
# Established Business Ownership                      943
# Entrepreneurial Employee Activity                   458
# Motivational Index                                  548
# Female/Male TEA                                     944
# Female/Male Opportunity-Driven TEA                  367
# High Job Creation Expectation                       941
# Innovation                                          489
# Business Services Sector                            906
# High Status to Successful Entrepreneurs             837
# Entrepreneurship as a Good Career Choice            834
# dtype: int64

# %% [markdown]
# ### Fear of failure rate--dealing with null value

# %%
# Fear of failure rate has just one null value. identifying the row or economy with null value

df_BA.loc[df_BA["Fear of failure rate *"].isna()]
# Out:
#      code    economy  year  Perceived opportunities  Perceived capabilities  \
# 736   582  Venezuela  2007                    56.04                   66.24
#
#      Fear of failure rate *  Entrepreneurial intentions  \
# 736                     NaN                       20.68
#
#      Total early-stage Entrepreneurial Activity (TEA)  \
# 736                                             20.16
#
#      Established Business Ownership  Entrepreneurial Employee Activity  \
# 736                            5.39                                NaN
#
#      Motivational Index  Female/Male TEA  Female/Male Opportunity-Driven TEA  \
# 736                 NaN             0.72                                 NaN
#
#      High Job Creation Expectation  Innovation  Business Services Sector  \
# 736                          25.62         NaN                      6.72
#
#      High Status to Successful Entrepreneurs  \
# 736                                     71.7
#
#      Entrepreneurship as a Good Career Choice
# 736                                     76.57

# %%
# pulling all the data point related to Venezuela
df_BA.loc[df_BA["economy"]=="Venezuela"]
# Out:
#      code    economy  year  Perceived opportunities  Perceived capabilities  \
# 538   582  Venezuela  2011                    48.45                   66.86
# 650   582  Venezuela  2009                    48.21                   59.31
# 736   582  Venezuela  2007                    56.04                   66.24
# 813   582  Venezuela  2005                    65.15                   74.94
# 878   582  Venezuela  2003                    43.04                   82.14
#
#      Fear of failure rate *  Entrepreneurial intentions  \
# 538                   24.15                       20.23
# 650                   25.61                       28.70
# 736                     NaN                       20.68
# 813                   30.95                       40.00
# 878                   30.73                       37.28
#
#      Total early-stage Entrepreneurial Activity (TEA)  \
# 538                                             15.43
# 650                                             18.66
# 736                                             20.16
# 813                                             24.95
# 878                                             26.81
#
#      Established Business Ownership  Entrepreneurial Employee Activity  \
# 538                            1.57                               0.63
# 650                            6.51                                NaN
# 736                            5.39                                NaN
# 813                            8.59                                NaN
# 878                            9.63                                NaN
#
#      Motivational Index  Female/Male TEA  Female/Male Opportunity-Driven TEA  \
# 538                1.52             0.88                                 NaN
# 650                 NaN             0.91                                 NaN
# 736                 NaN             0.72                                 NaN
# 813                 NaN             0.91                                 NaN
# 878                 NaN             0.88                                 NaN
#
#      High Job Creation Expectation  Innovation  Business Services Sector  \
# 538                            NaN       13.44                      6.49
# 650                          23.78         NaN                       NaN
# 736                          25.62         NaN                      6.72
# 813                          30.00         NaN                      8.67
# 878                          28.36         NaN                     10.08
#
#      High Status to Successful Entrepreneurs  \
# 538                                    77.26
# 650                                    68.88
# 736                                    71.70
# 813                                    77.00
# 878                                    73.01
#
#      Entrepreneurship as a Good Career Choice
# 538                                     83.06
# 650                                     76.24
# 736                                     76.57
# 813                                     84.32
# 878                                     79.67

# %% [markdown]
# #### Treating the one null value in Fear of Failure rate
# Since there are five data points, the one null value can be filled by calculating the mean from four other fear of
# failure rate data.

# %%
#calculating mean failure rate

mean_ffrate=df_BA.loc[(df_BA["economy"]=="Venezuela") & (df_BA["year"]!=2007),:]["Fear of failure rate *"].mean()

print(f"The data is updated with the mean value {mean_ffrate}")

# adding it to the df

df_BA["Fear of failure rate *"]=df_BA["Fear of failure rate *"].fillna(mean_ffrate)

#Displaying the DF with the changes made

df_BA.loc[df_BA["economy"]=="Venezuela"]
# Out:
# The data is updated with the mean value 27.86
#      code    economy  year  Perceived opportunities  Perceived capabilities  \
# 538   582  Venezuela  2011                    48.45                   66.86
# 650   582  Venezuela  2009                    48.21                   59.31
# 736   582  Venezuela  2007                    56.04                   66.24
# 813   582  Venezuela  2005                    65.15                   74.94
# 878   582  Venezuela  2003                    43.04                   82.14
#
#      Fear of failure rate *  Entrepreneurial intentions  \
# 538                   24.15                       20.23
# 650                   25.61                       28.70
# 736                   27.86                       20.68
# 813                   30.95                       40.00
# 878                   30.73                       37.28
#
#      Total early-stage Entrepreneurial Activity (TEA)  \
# 538                                             15.43
# 650                                             18.66
# 736                                             20.16
# 813                                             24.95
# 878                                             26.81
#
#      Established Business Ownership  Entrepreneurial Employee Activity  \
# 538                            1.57                               0.63
# 650                            6.51                                NaN
# 736                            5.39                                NaN
# 813                            8.59                                NaN
# 878                            9.63                                NaN
#
#      Motivational Index  Female/Male TEA  Female/Male Opportunity-Driven TEA  \
# 538                1.52             0.88                                 NaN
# 650                 NaN             0.91                                 NaN
# 736                 NaN             0.72                                 NaN
# 813                 NaN             0.91                                 NaN
# 878                 NaN             0.88                                 NaN
#
#      High Job Creation Expectation  Innovation  Business Services Sector  \
# 538                            NaN       13.44                      6.49
# 650                          23.78         NaN                       NaN
# 736                          25.62         NaN                      6.72
# 813                          30.00         NaN                      8.67
# 878                          28.36         NaN                     10.08
#
#      High Status to Successful Entrepreneurs  \
# 538                                    77.26
# 650                                    68.88
# 736                                    71.70
# 813                                    77.00
# 878                                    73.01
#
#      Entrepreneurship as a Good Career Choice
# 538                                     83.06
# 650                                     76.24
# 736                                     76.57
# 813                                     84.32
# 878                                     79.67

# %% [markdown]
# ### Entrepreneural intentions--dealing with null value
#
# All the economies that was surveyed in 2001 might not have questions on entrepreneurial intentions and hence the datapoint is null for all 28 economies.

# %%
#identifying the null values

df_BA.loc[df_BA["Entrepreneurial intentions"].isna()]
# Out:
#      code         economy  year  Perceived opportunities  \
# 916    54       Argentina  2001                    19.83
# 917    61       Australia  2001                    31.27
# 918    32         Belgium  2001                    19.96
# 919    55          Brazil  2001                    40.60
# 920   101          Canada  2001                    34.54
# 921    45         Denmark  2001                    45.78
# 922   358         Finland  2001                    54.91
# 923    33          France  2001                     6.89
# 924    49         Germany  2001                    23.65
# 925    36         Hungary  2001                     8.63
# 926    91           India  2001                    30.93
# 927   353         Ireland  2001                    34.26
# 928   972          Israel  2001                    17.98
# 929    39           Italy  2001                    47.85
# 930    81           Japan  2001                     6.95
# 931    52          Mexico  2001                    40.21
# 932    31     Netherlands  2001                    42.49
# 933    64     New Zealand  2001                    49.01
# 934    47          Norway  2001                    58.75
# 935    48          Poland  2001                    13.97
# 936   351        Portugal  2001                    22.28
# 937    65       Singapore  2001                    17.46
# 938    27    South Africa  2001                    19.70
# 939    82     South Korea  2001                    12.24
# 940    34           Spain  2001                    48.46
# 941    46          Sweden  2001                    42.34
# 942    44  United Kingdom  2001                    23.00
# 943     1   United States  2001                    34.89
#
#      Perceived capabilities  Fear of failure rate *  \
# 916                   54.80                   37.17
# 917                   59.66                   38.18
# 918                   30.32                   37.87
# 919                   54.28                   32.14
# 920                   53.03                   26.89
# 921                   40.81                   23.72
# 922                   37.61                   35.17
# 923                   20.01                   28.71
# 924                   30.11                   41.75
# 925                   55.30                   10.44
# 926                   39.85                   33.17
# 927                   46.28                   40.14
# 928                   35.64                   33.19
# 929                   33.36                   28.00
# 930                   10.98                   22.37
# 931                   50.18                   25.77
# 932                   36.52                   27.31
# 933                   66.26                   25.61
# 934                   36.43                   28.88
# 935                   38.57                   44.28
# 936                   41.70                   31.32
# 937                   24.56                   45.07
# 938                   30.38                   36.27
# 939                   28.55                   43.55
# 940                   48.65                   36.22
# 941                   44.41                   31.19
# 942                   45.96                   33.24
# 943                   60.59                   21.37
#
#      Entrepreneurial intentions  \
# 916                         NaN
# 917                         NaN
# 918                         NaN
# 919                         NaN
# 920                         NaN
# 921                         NaN
# 922                         NaN
# 923                         NaN
# 924                         NaN
# 925                         NaN
# 926                         NaN
# 927                         NaN
# 928                         NaN
# 929                         NaN
# 930                         NaN
# 931                         NaN
# 932                         NaN
# 933                         NaN
# 934                         NaN
# 935                         NaN
# 936                         NaN
# 937                         NaN
# 938                         NaN
# 939                         NaN
# 940                         NaN
# 941                         NaN
# 942                         NaN
# 943                         NaN
#
#      Total early-stage Entrepreneurial Activity (TEA)  \
# 916                                              9.92
# 917                                             14.68
# 918                                              4.19
# 919                                             13.80
# 920                                             10.27
# 921                                              7.23
# 922                                              8.16
# 923                                              5.72
# 924                                              6.28
# 925                                             10.86
# 926                                             10.81
# 927                                             11.37
# 928                                              5.29
# 929                                              9.11
# 930                                              3.10
# 931                                             17.91
# 932                                              5.87
# 933                                             15.45
# 934                                              7.40
# 935                                              8.04
# 936                                              6.61
# 937                                              6.05
# 938                                              6.49
# 939                                             14.32
# 940                                              6.32
# 941                                              5.65
# 942                                              6.49
# 943                                             11.07
#
#      Established Business Ownership  Entrepreneurial Employee Activity  \
# 916                            3.92                                NaN
# 917                           27.96                                NaN
# 918                            3.02                                NaN
# 919                            3.79                                NaN
# 920                            3.89                                NaN
# 921                            4.25                                NaN
# 922                            7.46                                NaN
# 923                            1.62                                NaN
# 924                            4.18                                NaN
# 925                            5.90                                NaN
# 926                            8.76                                NaN
# 927                            4.52                                NaN
# 928                             NaN                                NaN
# 929                            3.60                                NaN
# 930                            5.07                                NaN
# 931                            5.83                                NaN
# 932                            3.75                                NaN
# 933                           12.84                                NaN
# 934                            6.51                                NaN
# 935                            4.75                                NaN
# 936                            4.71                                NaN
# 937                            5.43                                NaN
# 938                            0.83                                NaN
# 939                           10.47                                NaN
# 940                            4.72                                NaN
# 941                            5.65                                NaN
# 942                            3.35                                NaN
# 943                            5.83                                NaN
#
#      Motivational Index  Female/Male TEA  Female/Male Opportunity-Driven TEA  \
# 916                 NaN             0.38                                 NaN
# 917                 NaN             0.48                                 NaN
# 918                 NaN             0.51                                 NaN
# 919                 NaN             0.62                                 NaN
# 920                 NaN             0.63                                 NaN
# 921                 NaN             0.43                                 NaN
# 922                 NaN             0.54                                 NaN
# 923                 NaN             0.43                                 NaN
# 924                 NaN             0.44                                 NaN
# 925                 NaN             0.57                                 NaN
# 926                 NaN             0.31                                 NaN
# 927                 NaN             0.43                                 NaN
# 928                 NaN             0.28                                 NaN
# 929                 NaN             0.97                                 NaN
# 930                 NaN             0.46                                 NaN
# 931                 NaN             0.51                                 NaN
# 932                 NaN             0.50                                 NaN
# 933                 NaN             0.76                                 NaN
# 934                 NaN             0.45                                 NaN
# 935                 NaN             0.65                                 NaN
# 936                 NaN             0.39                                 NaN
# 937                 NaN             0.39                                 NaN
# 938                 NaN             0.52                                 NaN
# 939                 NaN             0.42                                 NaN
# 940                 NaN             0.71                                 NaN
# 941                 NaN             0.59                                 NaN
# 942                 NaN             0.39                                 NaN
# 943                 NaN             0.68                                 NaN
#
#      High Job Creation Expectation  Innovation  Business Services Sector  \
# 916                          17.81         NaN                     16.72
# 917                          28.79         NaN                     30.32
# 918                          13.54         NaN                     18.85
# 919                          14.44         NaN                      9.70
# 920                          12.37         NaN                     27.06
# 921                           3.48         NaN                     43.89
# 922                          19.09         NaN                     35.07
# 923                           8.37         NaN                     24.89
# 924                          17.44         NaN                     32.00
# 925                          15.79         NaN                     20.25
# 926                           7.49         NaN                      5.91
# 927                          20.01         NaN                     21.43
# 928                          47.47         NaN                     52.21
# 929                          24.96         NaN                     23.68
# 930                          15.01         NaN                     17.62
# 931                          17.10         NaN                      8.24
# 932                          29.82         NaN                     46.86
# 933                          11.82         NaN                     27.51
# 934                          20.31         NaN                     31.88
# 935                          11.85         NaN                     17.44
# 936                          13.30         NaN                     14.68
# 937                          22.03         NaN                     18.84
# 938                          20.79         NaN                     32.25
# 939                          19.36         NaN                     15.83
# 940                          12.97         NaN                     22.38
# 941                          25.72         NaN                     34.33
# 942                          17.46         NaN                     27.53
# 943                          26.31         NaN                     30.56
#
#      High Status to Successful Entrepreneurs  \
# 916                                      NaN
# 917                                      NaN
# 918                                      NaN
# 919                                      NaN
# 920                                      NaN
# 921                                      NaN
# 922                                      NaN
# 923                                      NaN
# 924                                      NaN
# 925                                      NaN
# 926                                      NaN
# 927                                      NaN
# 928                                      NaN
# 929                                      NaN
# 930                                      NaN
# 931                                      NaN
# 932                                      NaN
# 933                                      NaN
# 934                                      NaN
# 935                                      NaN
# 936                                      NaN
# 937                                      NaN
# 938                                      NaN
# 939                                      NaN
# 940                                      NaN
# 941                                      NaN
# 942                                      NaN
# 943                                      NaN
#
#      Entrepreneurship as a Good Career Choice
# 916                                       NaN
# 917                                       NaN
# 918                                       NaN
# 919                                       NaN
# 920                                       NaN
# 921                                       NaN
# 922                                       NaN
# 923                                       NaN
# 924                                       NaN
# 925                                       NaN
# 926                                       NaN
# 927                                       NaN
# 928                                       NaN
# 929                                       NaN
# 930                                       NaN
# 931                                       NaN
# 932                                       NaN
# 933                                       NaN
# 934                                       NaN
# 935                                       NaN
# 936                                       NaN
# 937                                       NaN
# 938                                       NaN
# 939                                       NaN
# 940                                       NaN
# 941                                       NaN
# 942                                       NaN
# 943                                       NaN

# %% [markdown]
# ### Established Business Ownership- null values
#
# Replaced the single value with the closest data point.

# %%
df_BA.loc[df_BA['Established Business Ownership'].isna()]
# Out:
#      code economy  year  Perceived opportunities  Perceived capabilities  \
# 928   972  Israel  2001                    17.98                   35.64
#
#      Fear of failure rate *  Entrepreneurial intentions  \
# 928                   33.19                         NaN
#
#      Total early-stage Entrepreneurial Activity (TEA)  \
# 928                                              5.29
#
#      Established Business Ownership  Entrepreneurial Employee Activity  \
# 928                             NaN                                NaN
#
#      Motivational Index  Female/Male TEA  Female/Male Opportunity-Driven TEA  \
# 928                 NaN             0.28                                 NaN
#
#      High Job Creation Expectation  Innovation  Business Services Sector  \
# 928                          47.47         NaN                     52.21
#
#      High Status to Successful Entrepreneurs  \
# 928                                      NaN
#
#      Entrepreneurship as a Good Career Choice
# 928                                       NaN

# %%
df_BA.loc[df_BA['economy']=='Israel']
# Out:
#      code economy  year  Perceived opportunities  Perceived capabilities  \
# 18    972  Israel  2019                    46.00                   43.34
# 70    972  Israel  2018                    56.23                   41.48
# 121   972  Israel  2017                    58.29                   44.14
# 183   972  Israel  2016                    53.69                   41.10
# 243   972  Israel  2015                    55.50                   41.56
# 374   972  Israel  2013                    46.50                   36.17
# 445   972  Israel  2012                    30.62                   29.31
# 564   972  Israel  2010                    33.88                   39.94
# 619   972  Israel  2009                    28.99                   38.27
# 674   972  Israel  2008                    24.78                   37.83
# 713   972  Israel  2007                    23.98                   38.15
# 830   972  Israel  2004                    32.06                   42.21
# 896   972  Israel  2002                    25.69                   47.41
# 928   972  Israel  2001                    17.98                   35.64
#
#      Fear of failure rate *  Entrepreneurial intentions  \
# 18                    55.36                       21.20
# 70                    47.47                       26.20
# 121                   47.96                       26.42
# 183                   48.65                       20.61
# 243                   47.76                       21.59
# 374                   51.76                       23.97
# 445                   46.76                       12.81
# 564                   46.71                       13.45
# 619                   37.27                       13.62
# 674                   44.81                       14.19
# 713                   43.56                       12.63
# 830                   44.42                       16.62
# 896                   37.55                       14.43
# 928                   33.19                         NaN
#
#      Total early-stage Entrepreneurial Activity (TEA)  \
# 18                                              12.69
# 70                                              12.70
# 121                                             12.78
# 183                                             11.31
# 243                                             11.82
# 374                                             10.04
# 445                                              6.53
# 564                                              5.02
# 619                                              6.07
# 674                                              6.36
# 713                                              5.44
# 830                                              6.62
# 896                                              6.99
# 928                                              5.29
#
#      Established Business Ownership  Entrepreneurial Employee Activity  \
# 18                             5.45                               5.75
# 70                             4.20                               7.21
# 121                            3.32                               8.55
# 183                            4.00                               7.30
# 243                            3.90                               6.55
# 374                            5.94                                NaN
# 445                            3.78                               4.24
# 564                            3.25                                NaN
# 619                            4.27                                NaN
# 674                            4.12                                NaN
# 713                            2.36                                NaN
# 830                            3.92                                NaN
# 896                            5.66                                NaN
# 928                             NaN                                NaN
#
#      Motivational Index  Female/Male TEA  Female/Male Opportunity-Driven TEA  \
# 18                  NaN             0.69                                 NaN
# 70                 3.30             0.70                                1.10
# 121                2.02             0.72                                1.00
# 183                2.60             0.71                                1.15
# 243                3.29             0.65                                1.02
# 374                2.83             0.48                                1.03
# 445                2.41             0.72                                 NaN
# 564                2.24             0.50                                 NaN
# 619                 NaN             0.52                                 NaN
# 674                 NaN             0.46                                 NaN
# 713                 NaN             0.53                                 NaN
# 830                 NaN             0.54                                 NaN
# 896                 NaN             0.28                                 NaN
# 928                 NaN             0.28                                 NaN
#
#      High Job Creation Expectation  Innovation  Business Services Sector  \
# 18                           21.73         NaN                     27.06
# 70                           22.90       32.90                      7.30
# 121                           8.66       26.70                     27.30
# 183                          22.10       30.40                     37.37
# 243                          23.60       30.78                     32.90
# 374                          23.84       34.13                     31.91
# 445                          21.33       29.15                     24.05
# 564                          32.10         NaN                     26.90
# 619                          32.43         NaN                       NaN
# 674                          23.77         NaN                     33.65
# 713                          45.05         NaN                     33.13
# 830                          29.04         NaN                     17.27
# 896                          19.88         NaN                     17.13
# 928                          47.47         NaN                     52.21
#
#      High Status to Successful Entrepreneurs  \
# 18                                     84.13
# 70                                     84.98
# 121                                    86.07
# 183                                    85.50
# 243                                    86.24
# 374                                    80.30
# 445                                    72.39
# 564                                    73.23
# 619                                    73.24
# 674                                    74.13
# 713                                    65.72
# 830                                    64.12
# 896                                      NaN
# 928                                      NaN
#
#      Entrepreneurship as a Good Career Choice
# 18                                      64.21
# 70                                      65.96
# 121                                     65.16
# 183                                     64.20
# 243                                     64.48
# 374                                     60.61
# 445                                     59.47
# 564                                     60.12
# 619                                     61.40
# 674                                     56.23
# 713                                     50.16
# 830                                     62.35
# 896                                       NaN
# 928                                       NaN

# %%
#Replacing with the closest value.
df_BA["Established Business Ownership"]=df_BA["Established Business Ownership"].fillna(5.66)
df_BA.loc[df_BA['economy']=='Israel']
# Out:
#      code economy  year  Perceived opportunities  Perceived capabilities  \
# 18    972  Israel  2019                    46.00                   43.34
# 70    972  Israel  2018                    56.23                   41.48
# 121   972  Israel  2017                    58.29                   44.14
# 183   972  Israel  2016                    53.69                   41.10
# 243   972  Israel  2015                    55.50                   41.56
# 374   972  Israel  2013                    46.50                   36.17
# 445   972  Israel  2012                    30.62                   29.31
# 564   972  Israel  2010                    33.88                   39.94
# 619   972  Israel  2009                    28.99                   38.27
# 674   972  Israel  2008                    24.78                   37.83
# 713   972  Israel  2007                    23.98                   38.15
# 830   972  Israel  2004                    32.06                   42.21
# 896   972  Israel  2002                    25.69                   47.41
# 928   972  Israel  2001                    17.98                   35.64
#
#      Fear of failure rate *  Entrepreneurial intentions  \
# 18                    55.36                       21.20
# 70                    47.47                       26.20
# 121                   47.96                       26.42
# 183                   48.65                       20.61
# 243                   47.76                       21.59
# 374                   51.76                       23.97
# 445                   46.76                       12.81
# 564                   46.71                       13.45
# 619                   37.27                       13.62
# 674                   44.81                       14.19
# 713                   43.56                       12.63
# 830                   44.42                       16.62
# 896                   37.55                       14.43
# 928                   33.19                         NaN
#
#      Total early-stage Entrepreneurial Activity (TEA)  \
# 18                                              12.69
# 70                                              12.70
# 121                                             12.78
# 183                                             11.31
# 243                                             11.82
# 374                                             10.04
# 445                                              6.53
# 564                                              5.02
# 619                                              6.07
# 674                                              6.36
# 713                                              5.44
# 830                                              6.62
# 896                                              6.99
# 928                                              5.29
#
#      Established Business Ownership  Entrepreneurial Employee Activity  \
# 18                             5.45                               5.75
# 70                             4.20                               7.21
# 121                            3.32                               8.55
# 183                            4.00                               7.30
# 243                            3.90                               6.55
# 374                            5.94                                NaN
# 445                            3.78                               4.24
# 564                            3.25                                NaN
# 619                            4.27                                NaN
# 674                            4.12                                NaN
# 713                            2.36                                NaN
# 830                            3.92                                NaN
# 896                            5.66                                NaN
# 928                            5.66                                NaN
#
#      Motivational Index  Female/Male TEA  Female/Male Opportunity-Driven TEA  \
# 18                  NaN             0.69                                 NaN
# 70                 3.30             0.70                                1.10
# 121                2.02             0.72                                1.00
# 183                2.60             0.71                                1.15
# 243                3.29             0.65                                1.02
# 374                2.83             0.48                                1.03
# 445                2.41             0.72                                 NaN
# 564                2.24             0.50                                 NaN
# 619                 NaN             0.52                                 NaN
# 674                 NaN             0.46                                 NaN
# 713                 NaN             0.53                                 NaN
# 830                 NaN             0.54                                 NaN
# 896                 NaN             0.28                                 NaN
# 928                 NaN             0.28                                 NaN
#
#      High Job Creation Expectation  Innovation  Business Services Sector  \
# 18                           21.73         NaN                     27.06
# 70                           22.90       32.90                      7.30
# 121                           8.66       26.70                     27.30
# 183                          22.10       30.40                     37.37
# 243                          23.60       30.78                     32.90
# 374                          23.84       34.13                     31.91
# 445                          21.33       29.15                     24.05
# 564                          32.10         NaN                     26.90
# 619                          32.43         NaN                       NaN
# 674                          23.77         NaN                     33.65
# 713                          45.05         NaN                     33.13
# 830                          29.04         NaN                     17.27
# 896                          19.88         NaN                     17.13
# 928                          47.47         NaN                     52.21
#
#      High Status to Successful Entrepreneurs  \
# 18                                     84.13
# 70                                     84.98
# 121                                    86.07
# 183                                    85.50
# 243                                    86.24
# 374                                    80.30
# 445                                    72.39
# 564                                    73.23
# 619                                    73.24
# 674                                    74.13
# 713                                    65.72
# 830                                    64.12
# 896                                      NaN
# 928                                      NaN
#
#      Entrepreneurship as a Good Career Choice
# 18                                      64.21
# 70                                      65.96
# 121                                     65.16
# 183                                     64.20
# 243                                     64.48
# 374                                     60.61
# 445                                     59.47
# 564                                     60.12
# 619                                     61.40
# 674                                     56.23
# 713                                     50.16
# 830                                     62.35
# 896                                       NaN
# 928                                       NaN

# %% [markdown]
# ### Entrepreneurial employee activity, Motivational Index , Female/Male Opportunity-Driven TEA ,Innovation,High Status to Successful Entrepreneurs, Entrepreneurship as a Good Career Choice, Business Services Sector, High Job Creation Expectation --missing values
# These columns have more than 100 missing values and will be only used for plotting purposes.

# %%
print(f"Missing values in Entrepreneurial Employee Activity is :{len(df_BA.loc[df_BA['Entrepreneurial Employee Activity'].isna()])}")
print(f"Missing values in Motivational Index is :{len(df_BA.loc[df_BA['Motivational Index'].isna()])}")
print(f"Missing values in Female/Male Opportunity-Driven TEA is :{len(df_BA.loc[df_BA['Female/Male Opportunity-Driven TEA'].isna()])}")
print(f"Missing values in Innovation is :{len(df_BA.loc[df_BA['Innovation'].isna()])}")
print(f"Missing values in High Status to Successful Entrepreneurs is :{len(df_BA.loc[df_BA['High Status to Successful Entrepreneurs'].isna()])}")
print(f"Missing values in Entrepreneurship as a Good Career Choice is :{len(df_BA.loc[df_BA['Entrepreneurship as a Good Career Choice'].isna()])}")
print(f"Missing values in  Business Services Sector is :{len(df_BA.loc[df_BA['Business Services Sector'].isna()])}")
print(f"Missing values in High Job Creation Expectation is :{len(df_BA.loc[df_BA['High Job Creation Expectation'].isna()])}")
# Out:
# Missing values in Entrepreneurial Employee Activity is :486
# Missing values in Motivational Index is :396
# Missing values in Female/Male Opportunity-Driven TEA is :577
# Missing values in Innovation is :455
# Missing values in High Status to Successful Entrepreneurs is :107
# Missing values in Entrepreneurship as a Good Career Choice is :110
# Missing values in  Business Services Sector is :38
# Missing values in High Job Creation Expectation is :3
